# %%
import extract_data as ed
from functions import mean,skewness,kurtosis,central_moments
import graph as gh

# %%
file='../data/breast-cancer-cell-data.csv'
titles=ed.titles(file)

# %%
pairs=[[i,j] for i,j in enumerate(titles)]
pairs=pairs[2:]
for i in pairs:
    i[0]+=1
    i[1]=i[1][1:-1]
    
pairs[1][1]
# Out:
# 'texture_mean'

# %%
radius_mean=ed.extractinfo(file,pairs[0])

# %%
gh.histo_graph(radius_mean[1],30,radius_mean[0])

# %%
kurtosis(radius_mean[1])
# Out:
# 0.7411454202242869

# %%
gh.estimate_pdf(radius_mean[1])

# %%
texture_mean=ed.extractinfo(file,pairs[1])

# %%
gh.histo_graph(texture_mean[1],30,texture_mean[0])

# %%
gh.estimate_pdf(texture_mean[1])

# %%
fractal_dimension_se=ed.extractinfo(file,pairs[19])

# %%
kurtosis(fractal_dimension_se[1])
# Out:
# 0.9252876046135121

# %%
skewness(fractal_dimension_se[1])
# Out:
# 1.1002050372722152

# %%
central_moments(2,fractal_dimension_se[1])
# Out:
# 23.319169299650056

# %%
gh.histo_graph(fractal_dimension_se[1],40)

# %%
gh.boxplot(fractal_dimension_se[1])

# %%
gh.estimate_pdf(fractal_dimension_se[1])

# %%
newfile='../data/cancers-global.csv'

# %%
data=ed.pair_vals(newfile,1,7)

# %%
gh.estimate_pdf(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 gh.estimate_pdf(data)
#
# File ~/Desktop/p-word/python/mammo-da/pythonside/graph.py:62, in estimate_pdf(data, plot)
#      61 def estimate_pdf(data, plot=True):
# ---> 62     skewness = fn.skewness(data)
#      63     kurtosis = fn.kurtosis(data)
#      66     if np.abs(skewness) < 0.1 and np.abs(kurtosis) < 0.1:
#
# File ~/Desktop/p-word/python/mammo-da/pythonside/functions.py:115, in skewness(x)
#     114 def skewness(x):
# --> 115     num=central_moments(3,x)
#     116     den=central_moments(2,x)**(3/2)
#     117     return num/den
#
# File ~/Desktop/p-word/python/mammo-da/pythonside/functions.py:79, in central_moments(n, x)
#      76 ans = 0
#      78 for i in x:
# ---> 79     ans = ans + (i - mean(x)) ** (n)
#      81 return ans / len(x)
#
# File ~/Desktop/p-word/python/mammo-da/pythonside/functions.py:5, in mean(x)
#       4 def mean(x):
# ----> 5     return sum(x) / len(x)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
from functions import frequency
import extract_data as ed
import graph as gh
themain=ed.titles('../data/breast-cancer-cell-data.csv')

# %%
file='../data/breast-cancer-cell-data.csv'

# %%
radius_mean=ed.extractinfo(file,3)
radius_mean
# Out:
# [10.38,
#  17.77,
#  21.25,
#  20.38,
#  14.34,
#  15.7,
#  19.98,
#  20.83,
#  21.82,
#  24.04,
#  23.24,
#  17.89,
#  24.8,
#  23.95,
#  22.61,
#  27.54,
#  20.13,
#  20.68,
#  22.15,
#  14.36,
#  15.71,
#  12.44,
#  14.26,
#  23.04,
#  21.38,
#  16.4,
#  21.53,
#  20.25,
#  25.27,
#  15.05,
#  25.11,
#  18.7,
#  23.98,
#  26.47,
#  17.88,
#  21.59,
#  21.72,
#  18.42,
#  25.2,
#  20.82,
#  21.58,
#  21.35,
#  24.81,
#  20.28,
#  21.81,
#  17.6,
#  16.84,
#  18.66,
#  14.63,
#  22.3,
#  21.6,
#  16.34,
#  18.24,
#  18.7,
#  22.02,
#  18.75,
#  18.57,
#  21.59,
#  19.31,
#  11.79,
#  14.88,
#  20.98,
#  22.15,
#  13.86,
#  23.84,
#  23.94,
#  21.01,
#  19.04,
#  17.33,
#  16.49,
#  21.31,
#  14.64,
#  24.52,
#  15.79,
#  16.52,
#  19.65,
#  10.94,
#  16.15,
#  23.97,
#  18.0,
#  20.97,
#  15.86,
#  24.91,
#  26.29,
#  15.65,
#  18.52,
#  21.46,
#  24.59,
#  21.8,
#  15.24,
#  24.02,
#  22.76,
#  14.76,
#  18.3,
#  19.83,
#  23.03,
#  17.84,
#  19.94,
#  12.84,
#  19.77,
#  24.98,
# ...

# %%
gh.normal_graph(radius_mean)

# %%
gh.histo_graph(file,10,3)
